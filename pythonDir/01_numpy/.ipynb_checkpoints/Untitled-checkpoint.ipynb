# %%
from PIL import Image

# %%
img_path = 'img01.jpg'

# %%
img = Image.open(img_path).convert('L')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10832\4110079948.py in <module>
#       1 img = Image.open(img_path).convert('L')
# ----> 2 plt.imshow(img)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
type(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10832\818260518.py in <module>
# ----> 1 type(img)
#
# NameError: name 'img' is not defined

# %%
np.array(img)
# Out:
# array([[235, 237, 238, ..., 242, 242, 242],
#        [233, 233, 230, ..., 243, 242, 242],
#        [226, 224, 221, ..., 243, 243, 242],
#        ...,
#        [ 63,  61,  67, ...,  59,  55,  56],
#        [ 67,  67,  64, ...,  57,  57,  57],
#        [ 67,  67,  64, ...,  57,  57,  57]], dtype=uint8)

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=559x314>

# %%
import cv2
img = cv2.imread(img_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[227, 239, 237],
#         [229, 241, 241],
#         [230, 241, 245],
#         ...,
#         [242, 242, 244],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[223, 237, 238],
#         [223, 237, 240],
#         [220, 233, 241],
#         ...,
#         [243, 243, 245],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[215, 229, 238],
#         [213, 227, 238],
#         [210, 224, 237],
#         ...,
#         [243, 243, 245],
#         [243, 243, 245],
#         [242, 242, 244]],
#
#        ...,
#
#        [[ 57,  75,  17],
#         [ 55,  73,  15],
#         [ 61,  79,  21],
#         ...,
#         [ 51,  72,  15],
#         [ 47,  68,  11],
#         [ 48,  69,  12]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]]], dtype=uint8)

# %%
from PIL import Image

# %%
img_path = 'img01.jpg'

# %%
img = Image.open(img_path).convert('L')
plt.imshow(img)
plt.show()

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
np.array(img)
# Out:
# array([[235, 237, 238, ..., 242, 242, 242],
#        [233, 233, 230, ..., 243, 242, 242],
#        [226, 224, 221, ..., 243, 243, 242],
#        ...,
#        [ 63,  61,  67, ...,  59,  55,  56],
#        [ 67,  67,  64, ...,  57,  57,  57],
#        [ 67,  67,  64, ...,  57,  57,  57]], dtype=uint8)

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=559x314>

# %%
import cv2
img = cv2.imread(img_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[227, 239, 237],
#         [229, 241, 241],
#         [230, 241, 245],
#         ...,
#         [242, 242, 244],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[223, 237, 238],
#         [223, 237, 240],
#         [220, 233, 241],
#         ...,
#         [243, 243, 245],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[215, 229, 238],
#         [213, 227, 238],
#         [210, 224, 237],
#         ...,
#         [243, 243, 245],
#         [243, 243, 245],
#         [242, 242, 244]],
#
#        ...,
#
#        [[ 57,  75,  17],
#         [ 55,  73,  15],
#         [ 61,  79,  21],
#         ...,
#         [ 51,  72,  15],
#         [ 47,  68,  11],
#         [ 48,  69,  12]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10832\399247910.py in <module>
# ----> 1 plt.imshow(img)
#       2 plt.show()
#
# NameError: name 'plt' is not defined
