# %%
from PIL import Image

# %%
from scipy import misc

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img_path = 'img01.jpg'

# %%
img = Image.open(img_path)#.convert('L')
plt.imshow(img)
plt.show()

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
np.array(img)
# Out:
# array([[[227, 239, 235],
#         [229, 241, 239],
#         [230, 241, 245],
#         ...,
#         [242, 242, 242],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[223, 237, 237],
#         [223, 237, 238],
#         [220, 233, 239],
#         ...,
#         [243, 243, 245],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[215, 230, 237],
#         [213, 227, 236],
#         [210, 224, 237],
#         ...,
#         [243, 243, 245],
#         [243, 243, 245],
#         [242, 242, 244]],
#
#        ...,
#
#        [[ 57,  75,  17],
#         [ 55,  73,  15],
#         [ 61,  79,  21],
#         ...,
#         [ 51,  72,  16],
#         [ 47,  68,  12],
#         [ 48,  69,  13]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 58,  76,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]],
#
#        [[ 61,  79,  17],
#         [ 61,  79,  17],
#         [ 57,  77,  14],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]]], dtype=uint8)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=559x314>

# %%
import cv2
img = cv2.imread(img_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=559x314>

# %%
from PIL import Image

# %%
img_path = 'img01.jpg'

# %%
img = Image.open(img_path).convert('L')
plt.imshow(img)
plt.show()

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
np.array(img)
# Out:
# array([[235, 237, 238, ..., 242, 242, 242],
#        [233, 233, 230, ..., 243, 242, 242],
#        [226, 224, 221, ..., 243, 243, 242],
#        ...,
#        [ 63,  61,  67, ...,  59,  55,  56],
#        [ 67,  67,  64, ...,  57,  57,  57],
#        [ 67,  67,  64, ...,  57,  57,  57]], dtype=uint8)

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=559x314>

# %%
import cv2
img = cv2.imread(img_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img
# Out:
# array([[[227, 239, 237],
#         [229, 241, 241],
#         [230, 241, 245],
#         ...,
#         [242, 242, 244],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[223, 237, 238],
#         [223, 237, 240],
#         [220, 233, 241],
#         ...,
#         [243, 243, 245],
#         [242, 242, 244],
#         [242, 242, 244]],
#
#        [[215, 229, 238],
#         [213, 227, 238],
#         [210, 224, 237],
#         ...,
#         [243, 243, 245],
#         [243, 243, 245],
#         [242, 242, 244]],
#
#        ...,
#
#        [[ 57,  75,  17],
#         [ 55,  73,  15],
#         [ 61,  79,  21],
#         ...,
#         [ 51,  72,  15],
#         [ 47,  68,  11],
#         [ 48,  69,  12]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]],
#
#        [[ 61,  79,  19],
#         [ 61,  79,  19],
#         [ 57,  77,  16],
#         ...,
#         [ 49,  70,  14],
#         [ 49,  70,  14],
#         [ 49,  70,  14]]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()
