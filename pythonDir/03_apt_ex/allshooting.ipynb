# %%
import pandas as pd

# %%
from numpy import nan

# %%
import seaborn as sns

# %%
pd.read_csv('Mass Shootings - All Years.csv', encoding = 'cp949')
# Out:
#       Incident ID      Incident Date           State      City Or County  \
# 0         2035313      June 15, 2021         Alabama         Albertville
# 1         2035452      June 15, 2021        Illinois             Chicago
# 2         2034470      June 14, 2021         Florida       Boynton Beach
# 3         2034408      June 14, 2021        Michigan             Lansing
# 4         2033905      June 13, 2021            Ohio          West Salem
# ...           ...                ...             ...                 ...
# 1995       732927  December 24, 2016  North Carolina             Madison
# 1996       733176  December 24, 2016  North Carolina              Wilson
# 1997       732263  December 23, 2016         Alabama          Birmingham
# 1998       732574  December 23, 2016        Illinois             Chicago
# 1999       727759  December 17, 2016        Illinois  Chicago (Roseland)
#
#                                      Address  Killed  Injured  totalvictims  \
# ...

# %%
first_df = pd.read_csv('Mass Shootings - All Years.csv', encoding = 'cp949')

# %%
first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Incident ID     2000 non-null   int64
#  1   Incident Date   2000 non-null   object
#  2   State           2000 non-null   object
#  3   City Or County  2000 non-null   object
#  4   Address         1998 non-null   object
#  5   Killed          2000 non-null   int64
#  6   Injured         2000 non-null   int64
#  7   totalvictims    2000 non-null   int64
#  8   Operations      0 non-null      float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 140.8+ KB

# %%
first_df.groupby(['State'])['totalvictims'].sum()
# Out:
# State
# Alabama                  287
# Alaska                    13
# Arizona                  107
# Arkansas                 157
# California               917
# Colorado                 155
# Connecticut               72
# Delaware                  45
# District of Columbia     180
# Florida                  657
# Georgia                  330
# Idaho                      5
# Illinois                1051
# Indiana                  202
# Iowa                      49
# Kansas                    65
# Kentucky                 143
# Louisiana                478
# Maine                      9
# Maryland                 292
# Massachusetts             75
# Michigan                 263
# Minnesota                 97
# Mississippi              224
# Missouri                 346
# Montana                   14
# Nebraska                  33
# Nevada                   561
# New Jersey               267
# New Mexico                63
# New York                 411
# North Carolina           298
# ...

# %%
first_df.groupby(['State'])['totalvictims'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='State'>

# %%
high_first_df = first_df.head(10)
high_first_df
# Out:
#    Incident ID  Incident Date     State City Or County  \
# 0      2035313  June 15, 2021   Alabama    Albertville
# 1      2035452  June 15, 2021  Illinois        Chicago
# 2      2034470  June 14, 2021   Florida  Boynton Beach
# 3      2034408  June 14, 2021  Michigan        Lansing
# 4      2033905  June 13, 2021      Ohio     West Salem
# 5      2033605  June 13, 2021  Kentucky     Louisville
# 6      2033123  June 12, 2021      Ohio     Cincinnati
# 7      2032203  June 12, 2021  Illinois        Chicago
# 8      2032220  June 12, 2021     Texas         Austin
# 9      2032486  June 12, 2021      Ohio      Cleveland
#
#                          Address  Killed  Injured  totalvictims  Operations
# 0            956 Industrial Blvd       3        2             5         NaN
# 1               6221 S Morgan St       4        4             8         NaN
# 2                           I-95       1        3             4         NaN
# ...
