# %%
# !pwd
# Out:
# /content

# %%
import pandas as pd

# %%
pd.read_csv('drive/MyDrive/Colab Notebooks/sesac_deeplearning/final.csv', encoding='cp949')
# Out:
#         년     지역  면적 (ha)  10a당 생산량 (kg)  생산량 (톤)  평균기온(℃)  최고기온 평균(℃)  \
# 0    1980    강원도     1408            609     8574     15.6        21.0
# 1    1980    경기도     3723            406    15116     16.3        22.0
# 2    1980   경상남도     1786            600    10718     17.5        22.5
# 3    1980   경상북도    22667           1132   256590     16.7        21.9
# 4    1980  광주광역시        0              0        0     17.6        22.9
# ..    ...    ...      ...            ...      ...      ...         ...
# 633  2021   전라남도      208            787     1635     19.7        24.4
# 634  2021   전라북도     2033           1729    35142     19.1        24.7
# 635  2021    제주도        0              0        0     21.1        24.4
# 636  2021   충청남도     1551           1711    22757     19.0        24.5
# 637  2021   충청북도     3594           1451    52133     18.5        24.1
#
#      최저기온 평균(℃)  강수량(mm)  합계일조시간(hr)  ...  sp최저기온 평균(℃)  sp강수량(mm)  su평균기온(℃)  \
# 0          10.8   1080.5       264.1  ...           0.5      800.0       19.7
# 1          11.2    474.1       238.4  ...           0.8      397.5       19.9
# 2          12.9   1726.3       228.8  ...           4.0     1093.0       20.7
# 3          12.1   1368.3       239.6  ...           2.6      880.4       20.4
# 4          13.1    208.3       177.2  ...           3.8      133.4       20.9
# ..          ...      ...         ...  ...           ...        ...        ...
# 633        15.7   2292.8       224.7  ...           6.6     1328.2       22.0
# 634        14.4   1532.2       212.0  ...           5.0      673.7       21.7
# 635        18.3    881.0       209.0  ...          10.5      500.0       22.8
# 636        14.3    981.0       214.1  ...           4.6      533.7       21.7
# 637        13.5    738.9       203.3  ...           4.2      372.0       21.3
#
#      su최고기온 평균(℃)  su최저기온 평균(℃)  su강수량(mm)  fa평균기온(℃)  fa최고기온 평균(℃)  \
# 0            25.1          14.9     1167.3       18.6          23.8
# 1            25.3          15.1      550.6       20.2          25.8
# 2            25.7          16.1     1810.9       20.8          25.4
# 3            25.5          15.7     1469.3       20.0          24.6
# 4            25.9          16.5      217.7       21.3          26.4
# ..            ...           ...        ...        ...           ...
# 633          26.5          18.0     2765.2       24.3          28.4
# 634          27.2          17.1     1525.6       23.5          28.3
# 635          26.1          20.1      680.4       25.6          28.4
# 636          27.0          17.1      868.0       23.4          28.0
# 637          26.8          16.4      753.6       22.4          27.0
#
#      fa최저기온 평균(℃)  fa강수량(mm)
# 0            14.8     1230.9
# 1            15.7      436.0
# 2            17.0     2232.6
# 3            16.2     1704.6
# 4            17.4      269.1
# ..            ...        ...
# 633          21.2     2548.9
# 634          19.8     2400.6
# 635          23.3     1563.0
# 636          19.6     1597.8
# 637          18.6     1083.6
#
# [638 rows x 31 columns]

# %%
import sys

# %%
sys.version
# Out:
# '3.7.15 (default, Oct 12 2022, 19:14:55) \n[GCC 7.5.0]'

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# * 케라스는 텐서플로와 호환할 때 높은 유연성을 가짐
# * 모듈화하여 사용
# * 모델 : 케라스의 핵심.
# 1. 학습데이터 준비
# 2. 문제해결 모델 정의
# 3. loss, optimizer설정
# 4. 모델을 학습시키고 추론

# %% [markdown]
# * 데이터 전처리
# * 학습하기
# * 클래스 불균형 : SMOTE
# * 회귀와 분류
# * 원핫 인코딩 : 하나의 클래스만 1이고 나머지 클래스는 전부 0인 인코딩
# * 교차 검증
# * 하이퍼파라미터 : 사용자가 세팅해줘야하는 값. 주로 경험으로 결정함. 학습률, 매치크기, 에폭, 드롭아웃률 등이 있음.
# * 하이퍼파라미터 튜닝 : 파라미터값 조정. 그리드서치와 랜덤 서치 등을 주로 사용.
# * 배치와 배치 크기
# * 에폭과 스텝
# * 과대적합과 과소적합

# %% [markdown]
# * 텐서플로 기본연산

# %%
a = tf.constant(2) # 텐서를 선언

# %%
print(a)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)

# %%
print(tf.rank(a)) # 해당 텐서의 랭크를 계산
# Out:
# tf.Tensor(0, shape=(), dtype=int32)

# %%
b = tf.constant([1,2])
print(tf.rank(b))
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
