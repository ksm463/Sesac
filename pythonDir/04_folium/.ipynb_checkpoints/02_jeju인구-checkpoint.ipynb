# %%
import pandas as pd

# %%
pd.read_csv('jeju.csv', encoding='cp949')
# Out:
#       지역   읍면동          전화번호                            주소  \
# 0    제주시  일도1동  064-728-4412   제주특별자치도 제주시 중앙로7길 15 (일도일동)
# 1    제주시  일도2동  064-728-4442     제주특별자치도 제주시 고마로 28 (일도이동)
# 2    제주시  이도1동  064-728-1530  제주특별자치도 제주시 중앙로25길 17 (이도1동)
# 3    제주시  이도2동  064-755-2021     제주특별자치도 제주시 오복3길 8 (이도이동)
# 4    제주시  삼도1동  064-728-4532     제주특별자치도 제주시 전농로 40 (삼도일동)
# 5    제주시  삼도2동  064-728-4562   제주특별자치도 제주시 관덕로6길 15 (삼도이동)
# 6    제주시  용담1동  064-728-4592    제주특별자치도 제주시 용남3길 11 (용담일동)
# 7    제주시  용담2동  064-728-1535     제주특별자치도 제주시 흥운길 27 (용담이동)
# 8    제주시   건입동  064-728-1536      제주특별자치도 제주시 만덕로 18 (건입동)
# 9    제주시   화북동  064-728-4682   제주특별자치도 제주시 진남로6길 17 (화북일동)
# 10   제주시   삼양동  064-728-1538    제주특별자치도 제주시 지석13길 6 (삼양이동)
# 11   제주시   봉개동  064-728-4742          제주특별자치도 제주시 봉개북1길 15
# 12   제주시   아라동  064-728-1540      제주특별자치도 제주시 인다8길 5(아라일동)
# 13   제주시   오라동  064-728-1541  제주특별자치도 제주시 오라로 10길 6 (오라2동)
# 14   제주시    연동  064-728-4836      제주특별자치도 제주시 신대로 101 (연동)
# 15   제주시   노형동  064-728-4862    제주특별자치도 제주시 노형9길 9-4 (노형동)
# 16   제주시   외도동  064-728-4892  제주특별자치도 제주시 일주서로 7350 (외도이동)
# 17   제주시   이호동  064-728-1545     제주특별자치도 제주시 백포서길 9 (이호일동)
# 18   제주시   도두동  064-728-4952   제주특별자치도 제주시 도두1길 9-1 (도두일동)
# 19   제주시   한림읍  064-728-7628              제주시 한림읍 한림상로 132
# 20   제주시   애월읍  064-728-8809    제주특별자치도 제주시 애월읍 하귀로 21길 30
# 21   제주시   구좌읍  064-728-7713     제주특별자치도 제주시 구좌읍 일주동로 3116
# 22   제주시   조천읍  064-728-7813       제주특별자치도 제주시 조천읍 신북로 194
# 23   제주시   한경면  064-728-7913        제주특별자치도 제주시 한경면 칠전로 37
# 24   제주시   추자면  064-728-4264        제주특별자치도 제주시 추자면 추자로 26
# 25   제주시   우도면  064-728-1527       제주특별자치도 제주시 우도면 우도로 153
# 26  서귀포시   대정읍  064-760-4012     제주특별자치도 서귀포시 대정읍 하모중앙로 20
# 27  서귀포시   남원읍  064-760-4118      제주특별자치도 서귀포시 남원읍 태위로 695
# 28  서귀포시   성산읍  064-760-4214    제주특별자치도 서귀포시 성산읍 일주동로 4330
# 29  서귀포시   안덕면  064-760-4320     제주특별자치도 서귀포시 안덕면 화순서서로 74
# 30  서귀포시   표선면  064-760-4413     제주특별자치도 서귀포시 표선면 표선중앙로 74
# 31  서귀포시   송산동  064-760-4503      제주특별자치도 서귀포시 소암로 4 (서귀동)
# 32  서귀포시   정방동  064-760-4541       제주특별자치도 서귀포시 태평로421번길 7
# 33  서귀포시   중앙동  064-760-4562    제주특별자치도 서귀포시 동문동로 27 (서귀동)
# 34  서귀포시   천지동  064-760-4593  제주특별자치도 서귀포시 중정로47번길 3 (서귀동)
# 35  서귀포시   효돈동  064-767-1535   제주특별자치도 서귀포시 남선동산로 26 (하효동)
# 36  서귀포시   영천동  064-760-4664     제주특별자치도 서귀포시 토평로 15 (토평동)
# 37  서귀포시   동홍동  064-760-4682    제주특별자치도 서귀포시 동홍로 104 (동홍동)
# 38  서귀포시   서홍동  064-760-4745     제주특별자치도 서귀포시 중앙로 125(서홍동)
# 39  서귀포시   대륜동  064-760-4755  제주특별자치도 서귀포시 일주동로 9185 (법환동)
# 40  서귀포시   대천동  064-760-4785     제주특별자치도 서귀포시 도순로 44 (도순동)
# 41  서귀포시   중문동  064-760-4818   제주특별자치도 서귀포시 1100로 30 (중문동)
# 42  서귀포시   예래동  064-760-4864     제주특별자치도 서귀포시 예래로 82 (상예동)
#
#                                                  일반현황  \
# 0                      인구 3146명 / 면적 0.33㎢ / 11통 61개반
# 1                       인구 38400명 / 면적2.18㎢ / 48통326반
# 2                      인구 7418명 / 면적 0.79㎢ / 16통 97개반
# 3                      인구 41428명 / 면적 5.4㎢ / 49통 323반
# 4                       인구 14281명 / 면적0.87㎢ / 18통122반
# 5                        인구 9431명 / 면적0.83㎢ / 19통109반
# 6                        인구 8368명 / 면적0.61㎢ / 15통102반
# 7                     인구 16701명 / 면적 4.94㎢ / 23통 155반
# 8                        인구 10850명 / 면적2.5㎢ / 20통113반
# 9            인구 25559('17.5월 현재) / 면적8.28㎢ / 33통 205반
# 10        인구 25000명('19. 1.기준) / 면적 9.525㎢ / 23통 122반
# 11                         인구 3046명 / 면적47.2㎢ / 7통30반
# 12         인구 28741명('17.2.28기준) / 면적70.48㎢ / 24통126반
# 13                      인구 13729명 / 면적28.7㎢ / 17통74개반
# 14                       인구 39897 / 면적12.4㎢ / 41통268반
# 15     인구 56223명('18.12월 말 현재) / 면적 45.24㎢ / 58통 307반
# 16                     인구 17606명 / 면적 8.4㎢ / 19통 136반
# 17                       인구 4104명 / 면적 2.56㎢ / 8통 37반
# 18                       인구 2837명 / 면적 4.03㎢ / 6통 25반
# 19          인구 19925명 / 면적91.99㎢ / 21개리 56개자연마을 350개반
# 20           인구 26539명 / 면적202.16㎢ / 26개리70개자연마을317개반
# 21       인구 15080명 / 면적 185.82㎢ / 12개리 60동(자연마을) 220반
# 22                 인구 20804명 / 면적150.64㎢ / 12개리 244개반
# 23  인구 8745명('16.12.31.) / 면적79123㎢ / 15개리 51개자연마을...
# 24                 인구 2820명 / 면적7.05㎢ / 6개리 9개마을 44개반
# 25             인구 1718명 / 면적 6.07㎢ / 4개리 12개자연마을 20개반
# 26                 인구 16610명 / 면적 78.53㎢ / 23개리 240개반
# 27  인구 19151명 / 면적 188.70㎢ / 17개리 187개반('16.12.31 기준)
# 28               인구 13866명 / 면적 107.673㎢ / 14개리 152개반
# 29  인구 11867명 ('18.12.31.기준) / 면적 105.58㎢ / 12개리 1...
# 30                인구 11167명 / 면적 135.172㎢ / 10개리 94개반
# 31                        인구 5207명 / 면적 4.8㎢ / 2통 11반
# 32                                           인구 2444명
# 33          인구 4003명('17. 12. 31. 현재) 면적 0.45㎢ 8통 41반
# 34                       인구 3798명 / 면적 1.39㎢ / 6통 30반
# 35                         인구 5475명 / 면적 6.6㎢ / 2통 9반
# 36   2082 가구 4980명 / 면적 46.33㎢ / 5통 36반('12.12.31 현재)
# 37                    인구 22225명 / 면적 14.3㎢ / 11통 124반
# 38     인구 10697명('18.12.31. 현재) / 면적 13.34k㎡ / 5통 30반
# 39       인구 10344명('15.05.31일현재) / 면적 22.24㎢ / 4통 17반
# 40         인구 11310명 / 면적 50.5㎢ / 7통 51반 ('17.4.30기준)
# 41                     인구 10684명 / 면적 56.44㎢ / 4통 49반
# 42                       인구 3813명 / 면적 37.7㎢ / 5통 30반
#
#                                 청사현황  \
# 0                  지상 3층  / 연면적 585㎡
# 1          지상 2층·지하 1층 / 연면적 1307.01
# 2                  지상 2층 / 2층면적 205㎡
# 3         지하 1층·지상 3층 / 연면적 1223.52㎡
# 4          지하 1층·지상3층 / 연면적 2070.37㎡
# 5              지하 1층·지상3층 / 연면적 814㎡
# 6   지상 3층 / 대지면적 8825㎡ / 건축면적 428.55
# 7         지상 3층 지하 1층 / 연면적 1046.13㎡
# 8               지상 4층 / 연면적 1192.37㎡
# 9          지하 1층·지상3층 / 연면적 2375.80㎡
# 10        지하 1층·지상 3층 / 연면적 1688.11㎡
# 11             지하 1층·지상2층 / 연면적 770㎡
# 12          지하 1층·지상3층 / 연면적 453.26㎡
# 13            지하 1층·지상3층 / 연면적815.8㎡
# 14          지하 1층·지상3층 / 연면적 945.61㎡
# 15           지하 1층·지상3층 / 연면적 733.6㎡
# 16        지상 3층·지하 1층 / 연면적 1847.59㎡
# 17         지하 1층·지상 2층 / 연면적 543.81㎡
# 18             지상 2층·지하 1층 / 연면적646㎡
# 19              지상 2층 / 연면적 1066.33㎡
# 20           지하 1층·지상2층 / 연면적 618.6㎡
# 21                 지상 2층 / 연면적 1155㎡
# 22              지상 2층 / 연면적 1876.38㎡
# 23                지상 2층 / 연면적 602.4㎡
# 24          지하 1층·지상2층 / 연면적 705.46㎡
# 25                  지상 2층 / 연면적 402㎡
# 26     지상 2층·지하 1층 / 연면적 986.95㎡(본관)
# 27        지상 3층·지하 1층 / 연면적 1044.02㎡
# 28        지하 1층·지상 2층 / 연면적 1272.22㎡
# 29                             지상 2층
# 30                      지상 2 층 지하 1층
# 31           지상 3층 지하 1층 / 연면적 1077㎡
# 32         지상 3층 지하 1층 / 연면적 769.87㎡
# 33         지상 3층 지하 1층 (연면적 769.87㎡)
# 34             지상 2층 지하 1층 / 연면적646㎡
# 35                       지상 3층 지하 1층
# 36                       지상 2층 지하 1층
# 37        지상 2층 지하 1층 / 연면적 1934.31㎡
# 38                 지상 3층 / 연면적 1134㎡
# 39   지상 3층 / 연면적 914.28㎡(부지면적 2029㎡)
# 40               지상 2층 / 연면적 300.48㎡
# 41               지상 3층 / 연면적 2407.5㎡
# 42         지상 2층·지하 1층 / 연면적 449.14㎡
#
#                                         자치센터현황     데이터기준일자  Unnamed: 8
# 0                               개소일 2000-12-20  2019-06-20         NaN
# 1                 총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20         NaN
# 2                               개소일 2000-12-28  2019-06-20         NaN
# 3                 총면적 388.9㎡  / 개소일 2000-10-05  2019-06-20         NaN
# 4                                  총면적 456.55㎡  2019-06-20         NaN
# 5                 총면적 368.69㎡ / 개소일 2000-12-30  2019-06-20         NaN
# 6                연면적 112049㎡  / 개소일 2000-12-24  2019-06-20         NaN
# 7                 총면적 449.55㎡ / 개관일 2000-12-30  2019-06-20         NaN
# 8                 총면적 323.92㎡ / 개소일 2000-12-27  2019-06-20         NaN
# 9                     연면적 54㎡ / 개소일 2000-12-27  2019-06-20         NaN
# 10                 총면적 2034㎡  / 개소일 2000-12-28  2019-06-20         NaN
# 11                   총면적 390㎡ / 개소일 2000-10-05  2019-06-20         NaN
# 12                총면적 197.44㎡ / 개소일 2000-12-29  2019-06-20         NaN
# 13                 총면적 699.6㎡ / 개소일 2000-12-30  2019-06-20         NaN
# 14                              개소일 2001. 9. 5  2019-06-20         NaN
# 15                 총면적 733.6㎡ / 개소일 2000-12-31  2019-06-20         NaN
# 16                                 총면적 722.56㎡  2019-06-20         NaN
# 17  총면적 대지1047㎡ 건축면적 352.84㎡ /  개소일 2001-01-01  2019-06-20         NaN
# 18               총면적 142.41㎡  / 개소일 2000-12-30  2019-06-20         NaN
# 19              총면적 1066.33㎡ /  개소일 2007-07-19  2019-06-20         NaN
# 20                 대지면적 1592㎡ / 개소일 2006-03-11  2019-06-20         NaN
# 21                  총면적 1155㎡ / 개소일 2002-05-22  2019-06-20         NaN
# 22                 총면적 555.3㎡ / 개관일 2007-05-10  2019-06-20         NaN
# 23               총면적 3369.71㎡ / 개소일 2002-01-08  2019-06-20         NaN
# 24                 총면적 364.3㎡ / 개소일 2006-03-16  2019-06-20         NaN
# 25                 총면적 402㎡ / 개소일 : 2006-08-25  2019-06-20         NaN
# 26                   총면적 149㎡ / 개소일 2006-08-29  2019-06-20         NaN
# 27                  총면적 486m² / 개소일 2000-10-26  2019-06-20         NaN
# 28                       총면적 347.15㎡ 중 275.42㎡  2019-06-20         NaN
# 29                  총면적  155㎡ / 개소일 2000-11-14  2019-06-20         NaN
# 30                   총면적 214㎡ / 개소일 2006-08-16  2019-06-20         NaN
# 31                 총면적 276.6㎡ / 개소일 2000-12-28  2019-06-20         NaN
# 32                                         NaN  2019-06-20         NaN
# 33                                         NaN  2019-06-20         NaN
# 34                    총면적 53평 / 개소일 2001-01-05  2019-06-20         NaN
# 35                   총면적 147평 / 개소일 2000-12-29  2019-06-20         NaN
# 36                 총면적 136.5㎡ / 개소일 2001-01-04  2019-06-20         NaN
# 37                              개소일 2001-01-04  2019-06-20         NaN
# 38                총면적 631.47㎡ / 개소일 2000-12-27  2019-06-20         NaN
# 39                   총면적 526㎡ / 개소일 2001-01-05  2019-06-20         NaN
# 40                   총면적 90평 /  개소일 2000-12-28  2019-06-20         NaN
# 41                총면적 2407.5㎡ / 개소일 2000-11-02  2019-06-20         NaN
# 42                    총면적 47평 / 개소일 2000-12-27  2019-06-20         NaN

# %%
data = pd.read_csv('jeju.csv', encoding='cp949')
data.head(3)
# Out:
#     지역   읍면동          전화번호                            주소  \
# 0  제주시  일도1동  064-728-4412   제주특별자치도 제주시 중앙로7길 15 (일도일동)
# 1  제주시  일도2동  064-728-4442     제주특별자치도 제주시 고마로 28 (일도이동)
# 2  제주시  이도1동  064-728-1530  제주특별자치도 제주시 중앙로25길 17 (이도1동)
#
#                              일반현황                       청사현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반          지상 3층  / 연면적 585㎡
# 1   인구 38400명 / 면적2.18㎢ / 48통326반  지상 2층·지하 1층 / 연면적 1307.01
# 2  인구 7418명 / 면적 0.79㎢ / 16통 97개반          지상 2층 / 2층면적 205㎡
#
#                          자치센터현황     데이터기준일자  Unnamed: 8
# 0                개소일 2000-12-20  2019-06-20         NaN
# 1  총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20         NaN
# 2                개소일 2000-12-28  2019-06-20         NaN

# %%
REST_API_KEY = '817206ba6299992ca89b9a73c4eb355f'

# %%
curl -v -X GET "https://dapi.kakao.com/v2/local/search/address.json" \
  -H "Authorization: KakaoAK ${REST_API_KEY}" \
  --data-urlencode "query=전북 삼성동 100"
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_15248\2151965093.py", line 1
#     curl -v -X GET "https://dapi.kakao.com/v2/local/search/address.json" \
#                ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
url = 'https://dapi.kakao.com/v2/local/search/address.json?query=전북 삼성동 100&size=2'
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}

r = requests.get(url, headers=headers)

# %%
r.json()
# Out:
# {'documents': [{'address': {'address_name': '전북 익산시 부송동 100',
#     'b_code': '4514013400',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '부송동',
#     'sub_address_no': '',
#     'x': '126.99597495347',
#     'y': '35.9766482774579'},
#    'address_name': '전북 익산시 부송동 100',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.99597495347',
#    'y': '35.9766482774579'},
#   {'address': {'address_name': '전북 익산시 임상동 100',
#     'b_code': '4514013200',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '임상동',
#     'sub_address_no': '',
#     'x': '126.980268573424',
#     'y': '35.9816612949055'},
#    'address_name': '전북 익산시 임상동 100',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.980268573424',
#    'y': '35.9816612949055'}],
#  'meta': {'is_end': False, 'pageable_count': 3, 'total_count': 3}}

# %%
r.json()['documents'][0]['y'],r.json()['documents'][0]['x']
# Out:
# ('35.9766482774579', '126.99597495347')

# %%
r.json()
# Out:
# {'documents': [{'address': {'address_name': '전북 익산시 부송동 100',
#     'b_code': '4514013400',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '부송동',
#     'sub_address_no': '',
#     'x': '126.99597495347',
#     'y': '35.9766482774579'},
#    'address_name': '전북 익산시 부송동 100',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.99597495347',
#    'y': '35.9766482774579'},
#   {'address': {'address_name': '전북 익산시 임상동 100',
#     'b_code': '4514013200',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '임상동',
#     'sub_address_no': '',
#     'x': '126.980268573424',
#     'y': '35.9816612949055'},
#    'address_name': '전북 익산시 임상동 100',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.980268573424',
#    'y': '35.9816612949055'}],
#  'meta': {'is_end': False, 'pageable_count': 3, 'total_count': 3}}

# %%
url = 'https://dapi.kakao.com/v2/local/search/address.json?query=제주특별자치도 제주시 중앙로7길 15 (일도일동)&size=2'
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}

r = requests.get(url, headers=headers)

# %%
r.json()
# Out:
# {'documents': [{'address': {'address_name': '제주특별자치도 제주시 일도일동 1306-7',
#     'b_code': '5011010100',
#     'h_code': '5011051000',
#     'main_address_no': '1306',
#     'mountain_yn': 'N',
#     'region_1depth_name': '제주특별자치도',
#     'region_2depth_name': '제주시',
#     'region_3depth_h_name': '일도1동',
#     'region_3depth_name': '일도일동',
#     'sub_address_no': '7',
#     'x': '126.526377102562',
#     'y': '33.5150582697264'},
#    'address_name': '제주특별자치도 제주시 중앙로7길 15',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '제주특별자치도 제주시 중앙로7길 15',
#     'building_name': '일도1동주민센터',
#     'main_building_no': '15',
#     'region_1depth_name': '제주특별자치도',
#     'region_2depth_name': '제주시',
#     'region_3depth_name': '일도일동',
#     'road_name': '중앙로7길',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '126.526377102562',
#     'y': '33.5150582697264',
#     'zone_no': '63277'},
#    'x': '126.526377102562',
#    'y': '33.5150582697264'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
REST_API_KEY = '817206ba6299992ca89b9a73c4eb355f'

# %%
url = 'https://dapi.kakao.com/v2/local/search/address.json?query=제주특별자치도 제주시 중앙로7길 15 (일도일동)&category_group_code=P03'
headers = {'Authoriztion': f'KakaoAK {REST_API_KEY}'}

r = requests.get(url, headers=headers)

# %%
r.json()
# Out:
# {'errorType': 'AccessDeniedError',
#  'message': 'cannot find Authorization : KakaoAK header'}

# %%
data.head(1)
# Out:
#     지역   읍면동          전화번호                           주소  \
# 0  제주시  일도1동  064-728-4412  제주특별자치도 제주시 중앙로7길 15 (일도일동)
#
#                              일반현황               청사현황          자치센터현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반  지상 3층  / 연면적 585㎡  개소일 2000-12-20
#
#       데이터기준일자  Unnamed: 8
# 0  2019-06-20         NaN

# %%
#1. Unnamed: 8 컬럼제거

# %%
data.drop(columns=['Unnamed: 8'],inplace=True)

# %%
data.columns
# Out:
# Index(['지역', '읍면동', '전화번호', '주소', '일반현황', '청사현황', '자치센터현황', '데이터기준일자'], dtype='object')

# %%
#2. 주소에서 ()부분 제거

# %%
data['주소'] = data['주소'].str.split('(').str.get(0)

# %%
data.head(2)
# Out:
#     지역   읍면동          전화번호                     주소  \
# 0  제주시  일도1동  064-728-4412  제주특별자치도 제주시 중앙로7길 15
# 1  제주시  일도2동  064-728-4442    제주특별자치도 제주시 고마로 28
#
#                              일반현황                       청사현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반          지상 3층  / 연면적 585㎡
# 1   인구 38400명 / 면적2.18㎢ / 48통326반  지상 2층·지하 1층 / 연면적 1307.01
#
#                          자치센터현황     데이터기준일자
# 0                개소일 2000-12-20  2019-06-20
# 1  총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20

# %%
# 주소를 이용해서 카카오 로컬 키워드 검색을 이용해서 '위치' 컬럼에 [y, x] 저장
# 함수(get_yx)를 작성, apply를 이용해서 적용
# 결과값이 없을 경우 '결과없음'으로 처리

# %%
def get_yx(query): 
    import requests
    REST_API_KEY = '817206ba6299992ca89b9a73c4eb355f'
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=제주특별자치도 제주시 중앙로7길 15 (일도일동)&size=2'
    headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}

    r = requests.get(url, headers=headers)
    data = r.json()
    try:
        return [data['documents'][0]['y'],data['documents'][0]['x']]
    except:
        return '결과없음'

# %%
get_yx('제주특별자치도 제주시 중앙로7길 15')
# Out:
# ['33.5150582697264', '126.526377102562']

# %%
get_yx('제주특별자치도 제주시 고마로 28')
# Out:
# ['33.5150582697264', '126.526377102562']

# %%
data['주소'].apply(get_yx)
# Out:
# 0     [33.5150582697264, 126.526377102562]
# 1     [33.5150582697264, 126.526377102562]
# 2     [33.5150582697264, 126.526377102562]
# 3     [33.5150582697264, 126.526377102562]
# 4     [33.5150582697264, 126.526377102562]
# 5     [33.5150582697264, 126.526377102562]
# 6     [33.5150582697264, 126.526377102562]
# 7     [33.5150582697264, 126.526377102562]
# 8     [33.5150582697264, 126.526377102562]
# 9     [33.5150582697264, 126.526377102562]
# 10    [33.5150582697264, 126.526377102562]
# 11    [33.5150582697264, 126.526377102562]
# 12    [33.5150582697264, 126.526377102562]
# 13    [33.5150582697264, 126.526377102562]
# 14    [33.5150582697264, 126.526377102562]
# 15    [33.5150582697264, 126.526377102562]
# 16    [33.5150582697264, 126.526377102562]
# 17    [33.5150582697264, 126.526377102562]
# 18    [33.5150582697264, 126.526377102562]
# 19    [33.5150582697264, 126.526377102562]
# 20    [33.5150582697264, 126.526377102562]
# 21    [33.5150582697264, 126.526377102562]
# 22    [33.5150582697264, 126.526377102562]
# 23    [33.5150582697264, 126.526377102562]
# 24    [33.5150582697264, 126.526377102562]
# 25    [33.5150582697264, 126.526377102562]
# 26    [33.5150582697264, 126.526377102562]
# 27    [33.5150582697264, 126.526377102562]
# 28    [33.5150582697264, 126.526377102562]
# 29    [33.5150582697264, 126.526377102562]
# 30    [33.5150582697264, 126.526377102562]
# 31    [33.5150582697264, 126.526377102562]
# 32    [33.5150582697264, 126.526377102562]
# 33    [33.5150582697264, 126.526377102562]
# 34    [33.5150582697264, 126.526377102562]
# 35    [33.5150582697264, 126.526377102562]
# 36    [33.5150582697264, 126.526377102562]
# 37    [33.5150582697264, 126.526377102562]
# 38    [33.5150582697264, 126.526377102562]
# 39    [33.5150582697264, 126.526377102562]
# 40    [33.5150582697264, 126.526377102562]
# 41    [33.5150582697264, 126.526377102562]
# 42    [33.5150582697264, 126.526377102562]
# Name: 주소, dtype: object

# %%
data.head(3)
# Out:
#     지역   읍면동          전화번호                      주소  \
# 0  제주시  일도1동  064-728-4412   제주특별자치도 제주시 중앙로7길 15
# 1  제주시  일도2동  064-728-4442     제주특별자치도 제주시 고마로 28
# 2  제주시  이도1동  064-728-1530  제주특별자치도 제주시 중앙로25길 17
#
#                              일반현황                       청사현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반          지상 3층  / 연면적 585㎡
# 1   인구 38400명 / 면적2.18㎢ / 48통326반  지상 2층·지하 1층 / 연면적 1307.01
# 2  인구 7418명 / 면적 0.79㎢ / 16통 97개반          지상 2층 / 2층면적 205㎡
#
#                          자치센터현황     데이터기준일자
# 0                개소일 2000-12-20  2019-06-20
# 1  총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20
# 2                개소일 2000-12-28  2019-06-20

# %%
# '위치'컬럼의 값을 이용해서 마커를 생성하세요
# tooltip으로 '읍면동'컬럼을 값을 사용해서 지도에 표시합니다.(MarkerCluster이용)

# %%
import folium
from folium.plugins import MarkerCluster

# %%
jeju_loc = ['33.5150582697264', '126.526377102562']

# %%
m = folium.Map(jeju_loc, zoom_start=11)
mc = MarkerCluster().add_to(m)

def display(data,map):
    if data[0] != '결과없음':
        folium.Marker(data[0],tooltip=data[1]).add_to(map)
        
# data[['위치','읍면동']].apply(lambda x:display(x,map=mc),axis=1)
        
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1dfee466767c1a95fe60ce7e634c846 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1dfee466767c1a95fe60ce7e634c846&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1dfee466767c1a95fe60ce7e634c846 = L.map(
#                 &quot;map_f1dfee466767c1a95fe60ce7e634c846&quot;,
#                 {
#                     center: [33.5150582697264, 126.526377102562],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_070df693db83e280c00e8465954d523e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f1dfee466767c1a95fe60ce7e634c846);
#
#
#             var marker_cluster_daaa3586cbab61dea24cb08408841669 = L.markerClusterGroup(
#                 {}
#             );
#             map_f1dfee466767c1a95fe60ce7e634c846.addLayer(marker_cluster_daaa3586cbab61dea24cb08408841669);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data.head(2)
# Out:
#     지역   읍면동          전화번호                     주소  \
# 0  제주시  일도1동  064-728-4412  제주특별자치도 제주시 중앙로7길 15
# 1  제주시  일도2동  064-728-4442    제주특별자치도 제주시 고마로 28
#
#                              일반현황                       청사현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반          지상 3층  / 연면적 585㎡
# 1   인구 38400명 / 면적2.18㎢ / 48통326반  지상 2층·지하 1층 / 연면적 1307.01
#
#                          자치센터현황     데이터기준일자
# 0                개소일 2000-12-20  2019-06-20
# 1  총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20

# %%
# 일반현황에서 인구수를 추출 '인구수'칼럼을 추가 데이터 타입은 정수형태로 저장

# %%
import re

# %%
data['일반현황'].apply(lambda x : int(re.search('[0-9]{4,}',x).group()))
# Out:
# 0      3146
# 1     38400
# 2      7418
# 3     41428
# 4     14281
# 5      9431
# 6      8368
# 7     16701
# 8     10850
# 9     25559
# 10    25000
# 11     3046
# 12    28741
# 13    13729
# 14    39897
# 15    56223
# 16    17606
# 17     4104
# 18     2837
# 19    19925
# 20    26539
# 21    15080
# 22    20804
# 23     8745
# 24     2820
# 25     1718
# 26    16610
# 27    19151
# 28    13866
# 29    11867
# 30    11167
# 31     5207
# 32     2444
# 33     4003
# 34     3798
# 35     5475
# 36     2082
# 37    22225
# 38    10697
# 39    10344
# 40    11310
# 41    10684
# 42     3813
# Name: 일반현황, dtype: int64

# %%
data['일반현황']
# Out:
# 0                        인구 3146명 / 면적 0.33㎢ / 11통 61개반
# 1                         인구 38400명 / 면적2.18㎢ / 48통326반
# 2                        인구 7418명 / 면적 0.79㎢ / 16통 97개반
# 3                        인구 41428명 / 면적 5.4㎢ / 49통 323반
# 4                         인구 14281명 / 면적0.87㎢ / 18통122반
# 5                          인구 9431명 / 면적0.83㎢ / 19통109반
# 6                          인구 8368명 / 면적0.61㎢ / 15통102반
# 7                       인구 16701명 / 면적 4.94㎢ / 23통 155반
# 8                          인구 10850명 / 면적2.5㎢ / 20통113반
# 9              인구 25559('17.5월 현재) / 면적8.28㎢ / 33통 205반
# 10          인구 25000명('19. 1.기준) / 면적 9.525㎢ / 23통 122반
# 11                           인구 3046명 / 면적47.2㎢ / 7통30반
# 12           인구 28741명('17.2.28기준) / 면적70.48㎢ / 24통126반
# 13                        인구 13729명 / 면적28.7㎢ / 17통74개반
# 14                         인구 39897 / 면적12.4㎢ / 41통268반
# 15       인구 56223명('18.12월 말 현재) / 면적 45.24㎢ / 58통 307반
# 16                       인구 17606명 / 면적 8.4㎢ / 19통 136반
# 17                         인구 4104명 / 면적 2.56㎢ / 8통 37반
# 18                         인구 2837명 / 면적 4.03㎢ / 6통 25반
# 19            인구 19925명 / 면적91.99㎢ / 21개리 56개자연마을 350개반
# 20             인구 26539명 / 면적202.16㎢ / 26개리70개자연마을317개반
# 21         인구 15080명 / 면적 185.82㎢ / 12개리 60동(자연마을) 220반
# 22                   인구 20804명 / 면적150.64㎢ / 12개리 244개반
# 23    인구 8745명('16.12.31.) / 면적79123㎢ / 15개리 51개자연마을...
# 24                   인구 2820명 / 면적7.05㎢ / 6개리 9개마을 44개반
# 25               인구 1718명 / 면적 6.07㎢ / 4개리 12개자연마을 20개반
# 26                   인구 16610명 / 면적 78.53㎢ / 23개리 240개반
# 27    인구 19151명 / 면적 188.70㎢ / 17개리 187개반('16.12.31 기준)
# 28                 인구 13866명 / 면적 107.673㎢ / 14개리 152개반
# 29    인구 11867명 ('18.12.31.기준) / 면적 105.58㎢ / 12개리 1...
# 30                  인구 11167명 / 면적 135.172㎢ / 10개리 94개반
# 31                          인구 5207명 / 면적 4.8㎢ / 2통 11반
# 32                                             인구 2444명
# 33            인구 4003명('17. 12. 31. 현재) 면적 0.45㎢ 8통 41반
# 34                         인구 3798명 / 면적 1.39㎢ / 6통 30반
# 35                           인구 5475명 / 면적 6.6㎢ / 2통 9반
# 36     2082 가구 4980명 / 면적 46.33㎢ / 5통 36반('12.12.31 현재)
# 37                      인구 22225명 / 면적 14.3㎢ / 11통 124반
# 38       인구 10697명('18.12.31. 현재) / 면적 13.34k㎡ / 5통 30반
# 39         인구 10344명('15.05.31일현재) / 면적 22.24㎢ / 4통 17반
# 40           인구 11310명 / 면적 50.5㎢ / 7통 51반 ('17.4.30기준)
# 41                       인구 10684명 / 면적 56.44㎢ / 4통 49반
# 42                         인구 3813명 / 면적 37.7㎢ / 5통 30반
# Name: 일반현황, dtype: object

# %%
data['일반현황'].str.split('/').str.get(0)
# Out:
# 0                                     인구 3146명
# 1                                    인구 38400명
# 2                                     인구 7418명
# 3                                    인구 41428명
# 4                                    인구 14281명
# 5                                     인구 9431명
# 6                                     인구 8368명
# 7                                    인구 16701명
# 8                                    인구 10850명
# 9                          인구 25559('17.5월 현재)
# 10                        인구 25000명('19. 1.기준)
# 11                                    인구 3046명
# 12                       인구 28741명('17.2.28기준)
# 13                                   인구 13729명
# 14                                    인구 39897
# 15                     인구 56223명('18.12월 말 현재)
# 16                                   인구 17606명
# 17                                    인구 4104명
# 18                                    인구 2837명
# 19                                   인구 19925명
# 20                                   인구 26539명
# 21                                   인구 15080명
# 22                                   인구 20804명
# 23                        인구 8745명('16.12.31.)
# 24                                    인구 2820명
# 25                                    인구 1718명
# 26                                   인구 16610명
# 27                                   인구 19151명
# 28                                   인구 13866명
# 29                    인구 11867명 ('18.12.31.기준)
# 30                                   인구 11167명
# 31                                    인구 5207명
# 32                                     인구 2444명
# 33    인구 4003명('17. 12. 31. 현재) 면적 0.45㎢ 8통 41반
# 34                                    인구 3798명
# 35                                    인구 5475명
# 36                               2082 가구 4980명
# 37                                   인구 22225명
# 38                    인구 10697명('18.12.31. 현재)
# 39                     인구 10344명('15.05.31일현재)
# 40                                   인구 11310명
# 41                                   인구 10684명
# 42                                    인구 3813명
# Name: 일반현황, dtype: object

# %%
data['일반현황'].str.split('/').str.get(0).str.split().str.get(1)
# Out:
# 0                    3146명
# 1                   38400명
# 2                    7418명
# 3                   41428명
# 4                   14281명
# 5                    9431명
# 6                    8368명
# 7                   16701명
# 8                   10850명
# 9             25559('17.5월
# 10             25000명('19.
# 11                   3046명
# 12      28741명('17.2.28기준)
# 13                  13729명
# 14                   39897
# 15          56223명('18.12월
# 16                  17606명
# 17                   4104명
# 18                   2837명
# 19                  19925명
# 20                  26539명
# 21                  15080명
# 22                  20804명
# 23       8745명('16.12.31.)
# 24                   2820명
# 25                   1718명
# 26                  16610명
# 27                  19151명
# 28                  13866명
# 29                  11867명
# 30                  11167명
# 31                   5207명
# 32                   2444명
# 33              4003명('17.
# 34                   3798명
# 35                   5475명
# 36                      가구
# 37                  22225명
# 38       10697명('18.12.31.
# 39    10344명('15.05.31일현재)
# 40                  11310명
# 41                  10684명
# 42                   3813명
# Name: 일반현황, dtype: object

# %%
data['일반현황'].str.split('/').str.get(0).str.split('(').str.get(0)
# Out:
# 0          인구 3146명
# 1         인구 38400명
# 2          인구 7418명
# 3         인구 41428명
# 4         인구 14281명
# 5          인구 9431명
# 6          인구 8368명
# 7         인구 16701명
# 8         인구 10850명
# 9           인구 25559
# 10         인구 25000명
# 11         인구 3046명
# 12         인구 28741명
# 13        인구 13729명
# 14         인구 39897
# 15         인구 56223명
# 16        인구 17606명
# 17         인구 4104명
# 18         인구 2837명
# 19        인구 19925명
# 20        인구 26539명
# 21        인구 15080명
# 22        인구 20804명
# 23          인구 8745명
# 24         인구 2820명
# 25         인구 1718명
# 26        인구 16610명
# 27        인구 19151명
# 28        인구 13866명
# 29        인구 11867명
# 30        인구 11167명
# 31         인구 5207명
# 32          인구 2444명
# 33          인구 4003명
# 34         인구 3798명
# 35         인구 5475명
# 36    2082 가구 4980명
# 37        인구 22225명
# 38         인구 10697명
# 39         인구 10344명
# 40        인구 11310명
# 41        인구 10684명
# 42         인구 3813명
# Name: 일반현황, dtype: object

# %%
data['일반현황'].str.split('/').str.get(0).str.split('(').str.get(0).str.split().str.get(-1)
# Out:
# 0      3146명
# 1     38400명
# 2      7418명
# 3     41428명
# 4     14281명
# 5      9431명
# 6      8368명
# 7     16701명
# 8     10850명
# 9      25559
# 10    25000명
# 11     3046명
# 12    28741명
# 13    13729명
# 14     39897
# 15    56223명
# 16    17606명
# 17     4104명
# 18     2837명
# 19    19925명
# 20    26539명
# 21    15080명
# 22    20804명
# 23     8745명
# 24     2820명
# 25     1718명
# 26    16610명
# 27    19151명
# 28    13866명
# 29    11867명
# 30    11167명
# 31     5207명
# 32     2444명
# 33     4003명
# 34     3798명
# 35     5475명
# 36     4980명
# 37    22225명
# 38    10697명
# 39    10344명
# 40    11310명
# 41    10684명
# 42     3813명
# Name: 일반현황, dtype: object

# %%
data['일반현황'].str.split('/').str.get(0).str.split('(').str.get(0).str.split().str.get(-1).str.replace('명','').astype('int')
# Out:
# 0      3146
# 1     38400
# 2      7418
# 3     41428
# 4     14281
# 5      9431
# 6      8368
# 7     16701
# 8     10850
# 9     25559
# 10    25000
# 11     3046
# 12    28741
# 13    13729
# 14    39897
# 15    56223
# 16    17606
# 17     4104
# 18     2837
# 19    19925
# 20    26539
# 21    15080
# 22    20804
# 23     8745
# 24     2820
# 25     1718
# 26    16610
# 27    19151
# 28    13866
# 29    11867
# 30    11167
# 31     5207
# 32     2444
# 33     4003
# 34     3798
# 35     5475
# 36     4980
# 37    22225
# 38    10697
# 39    10344
# 40    11310
# 41    10684
# 42     3813
# Name: 일반현황, dtype: int32

# %%
data.head(1)
# Out:
#     지역   읍면동          전화번호                     주소  \
# 0  제주시  일도1동  064-728-4412  제주특별자치도 제주시 중앙로7길 15
#
#                              일반현황               청사현황          자치센터현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반  지상 3층  / 연면적 585㎡  개소일 2000-12-20
#
#       데이터기준일자
# 0  2019-06-20

# %%
data.지역.value_counts()
# Out:
# 제주시     26
# 서귀포시    17
# Name: 지역, dtype: int64

# %%
data['지역'].replace(['제주시','서귀포시'],["jeju","Seoqwipo"])
# Out:
# 0         jeju
# 1         jeju
# 2         jeju
# 3         jeju
# 4         jeju
# 5         jeju
# 6         jeju
# 7         jeju
# 8         jeju
# 9         jeju
# 10        jeju
# 11        jeju
# 12        jeju
# 13        jeju
# 14        jeju
# 15        jeju
# 16        jeju
# 17        jeju
# 18        jeju
# 19        jeju
# 20        jeju
# 21        jeju
# 22        jeju
# 23        jeju
# 24        jeju
# 25        jeju
# 26    Seoqwipo
# 27    Seoqwipo
# 28    Seoqwipo
# 29    Seoqwipo
# 30    Seoqwipo
# 31    Seoqwipo
# 32    Seoqwipo
# 33    Seoqwipo
# 34    Seoqwipo
# 35    Seoqwipo
# 36    Seoqwipo
# 37    Seoqwipo
# 38    Seoqwipo
# 39    Seoqwipo
# 40    Seoqwipo
# 41    Seoqwipo
# 42    Seoqwipo
# Name: 지역, dtype: object

# %%
data['지역명'] = data['지역'].replace(['제주시','서귀포시'],["jeju","Seoqwipo"])

# %%
data.head(2)
# Out:
#     지역   읍면동          전화번호                     주소  \
# 0  제주시  일도1동  064-728-4412  제주특별자치도 제주시 중앙로7길 15
# 1  제주시  일도2동  064-728-4442    제주특별자치도 제주시 고마로 28
#
#                              일반현황                       청사현황  \
# 0  인구 3146명 / 면적 0.33㎢ / 11통 61개반          지상 3층  / 연면적 585㎡
# 1   인구 38400명 / 면적2.18㎢ / 48통326반  지상 2층·지하 1층 / 연면적 1307.01
#
#                          자치센터현황     데이터기준일자   지역명
# 0                개소일 2000-12-20  2019-06-20  jeju
# 1  총면적 617.22㎡ / 개소일 2000-12-24  2019-06-20  jeju

# %%
result = data.groupby(['지역명'])['인구'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15248\1364921328.py in <module>
# ----> 1 result = data.groupby(['지역명'])['인구'].sum().reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: 인구'

# %%
import json

# %%
m = folium.Map(jeju_loc,zoom_start=11)
jsonfile = open('jejusi.json','r')
jsondata = json.loads(jsonfile.read())
folium.Choropleth(jsondata,
                  data=result,
                  columns=['지역명','인구'],
                  key_on='feature.id') add_to(m)
m
